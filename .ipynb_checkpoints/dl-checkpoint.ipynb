# %%
import pandas as pd
data = pd.read_csv("Lingual_data.csv")

# Basic Info
data_info = {
    "Dimensions": data.shape,
    "Column Names": list(data.columns),
    "Column Types": {col: dtype for col, dtype in zip(data.columns, data.dtypes)},
    "Null Values Count": {col: count for col, count in data.isnull().sum().items()},
    "Preview": data.head()
}

data_info
# Out:
# {'Dimensions': (32102, 2),
#  'Column Names': ['Cleaned_Text', 'Language'],
#  'Column Types': {'Cleaned_Text': dtype('O'), 'Language': dtype('O')},
#  'Null Values Count': {'Cleaned_Text': 0, 'Language': 0},
#  'Preview':                                         Cleaned_Text Language
#  0  برنامج لازم نفهم حيث يقدم البرنامج الذي يقدمه ...   Arabic
#  1  كانت ستعيش حياتها في ذلك اليوم جاء صديقان لزيا...   Arabic
#  2  مجرد التفكير في تلك الأم المسكينة النرجسية كان...   Arabic
#  3  لقد كان حلمًا مغرورًا جدًا يا أمي ، فأنت لا تع...   Arabic
#  4  وأنت تعرف أن أفضل جزء منه كان عندما كنت أرتدي ...   Arabic}

# %%
# Define the column name for languages
language_column = 'Language'

# Display unique languages in the dataset before updating
unique_languages_before = data[language_column].unique()
print("Unique languages in the dataset before updating:")
print(unique_languages_before)

# Correcting the spelling of specific language
data[language_column] = data[language_column].replace({'Sweedish': 'Swedish'})

# Display unique languages in the dataset after updating
unique_languages_after = data[language_column].unique()
print("Unique languages in the dataset after updating:")
print(unique_languages_after)

# Save the updated dataset to a CSV file
output_file = 'Lingual_data_cleaned.csv'
data.to_csv(output_file, index=False)

print(f"The cleaned dataset has been successfully saved as {output_file}")
# Out:
# Unique languages in the dataset before updating:
# ['Arabic' 'Chinese' 'Danish' 'Dutch' 'English' 'Estonian' 'French'
#  'German' 'Greek' 'Hindi' 'Indonesian' 'Italian' 'Japanese' 'Kannada'
#  'Korean' 'Latin' 'Malayalam' 'Persian' 'Portugeese' 'Portugese' 'Pushto'
#  'Romanian' 'Russian' 'Spanish' 'Swedish' 'Tamil' 'Thai' 'Turkish' 'Urdu']
# Unique languages in the dataset after updating:
# ['Arabic' 'Chinese' 'Danish' 'Dutch' 'English' 'Estonian' 'French'
#  'German' 'Greek' 'Hindi' 'Indonesian' 'Italian' 'Japanese' 'Kannada'
#  'Korean' 'Latin' 'Malayalam' 'Persian' 'Portugeese' 'Portugese' 'Pushto'
#  'Romanian' 'Russian' 'Spanish' 'Swedish' 'Tamil' 'Thai' 'Turkish' 'Urdu']
# The cleaned dataset has been successfully saved as Lingual_data_cleaned.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import nltk
from nltk.corpus import stopwords

# Load the dataset
data = pd.read_csv("Lingual_data_cleaned.csv")

# Step 1: Basic Dataset Exploration
print("Dataset Overview:")
print(f"Shape: {data.shape}")
print(f"Columns: {list(data.columns)}")
print("\nData Types:\n", data.dtypes)
print("\nMissing Values Per Column:\n", data.isnull().sum())
print("\nSample of Data:\n", data.head())
print("\nNumber of Duplicate Rows:", data.duplicated().sum())

# Step 2: Class Distribution Analysis
if "Language" in data.columns:
    print("\nLanguage Distribution Summary:")
    print(data["Language"].value_counts())

    # Visualize language distribution with a pie chart
    plt.figure(figsize=(8, 8))
    data["Language"].value_counts().plot.pie(
        autopct='%1.1f%%', startangle=140, cmap='coolwarm', explode=[0.1] + [0] * (data["Language"].nunique() - 1)
    )
    plt.title("Language Distribution (Pie Chart)")
    plt.ylabel("")  # Hide the y-label for better aesthetics
    plt.tight_layout()
    plt.show()

    # Visualize language distribution with a bar chart
    plt.figure(figsize=(10, 6))
    sns.barplot(
        y=data["Language"].value_counts().index,
        x=data["Language"].value_counts().values,
        palette="viridis"
    )
    plt.title("Language Distribution in Dataset")
    plt.xlabel("Count")
    plt.ylabel("Language")
    plt.tight_layout()
    plt.show()
# Out:
# Dataset Overview:
# Shape: (32102, 2)
# Columns: ['Cleaned_Text', 'Language']
#
# Data Types:
#  Cleaned_Text    object
# Language        object
# dtype: object
#
# Missing Values Per Column:
#  Cleaned_Text    0
# Language        0
# dtype: int64
#
# Sample of Data:
#                                          Cleaned_Text Language
# 0  برنامج لازم نفهم حيث يقدم البرنامج الذي يقدمه ...   Arabic
# 1  كانت ستعيش حياتها في ذلك اليوم جاء صديقان لزيا...   Arabic
# 2  مجرد التفكير في تلك الأم المسكينة النرجسية كان...   Arabic
# 3  لقد كان حلمًا مغرورًا جدًا يا أمي ، فأنت لا تع...   Arabic
# 4  وأنت تعرف أن أفضل جزء منه كان عندما كنت أرتدي ...   Arabic
#
# Number of Duplicate Rows: 0
#
# Language Distribution Summary:
# Language
# English       2382
# French        1996
# Spanish       1809
# Russian       1684
# Swedish       1663
# Dutch         1536
# Arabic        1529
# Turkish       1467
# Tamil         1444
# Hindi         1052
# Japanese      1000
# Korean        1000
# ...

# %%
import re

# Step 3: Preprocessing
# Handle missing values
data.dropna(inplace=True)

# Remove duplicates
data.drop_duplicates(inplace=True)
print("\nDuplicate Rows After Handling:", data.duplicated().sum())

# Clean text
def clean_text(text):
    text = re.sub(r'\\', '', text)       # Remove backslashes
    text = re.sub(r'\n', ' ', text)      # Replace line breaks with a space
    text = re.sub(r'\s+', ' ', text)     # Replace multiple spaces with a single space
    text = re.sub(r'[^\w\s]', '', text)  # Remove special characters
    text = re.sub(r'\d+', '', text)      # Remove numbers
    text = text.strip()                   # Remove leading and trailing whitespaces
    return text

# Before cleaning dataset
print("Dataset before cleaning:\n", data.head())

data['Cleaned_Text'] = data['Cleaned_Text'].apply(clean_text)

# After cleaning dataset
print("Dataset after cleaning:\n", data.head())

# Save clean dataset
data.to_csv("new_merged_dataset.csv", index=False)
# Out:
# Duplicate Rows After Handling: 0
# Dataset before cleaning:
#                                          Cleaned_Text Language
# 0  برنامج لازم نفهم حيث يقدم البرنامج الذي يقدمه ...   Arabic
# 1  كانت ستعيش حياتها في ذلك اليوم جاء صديقان لزيا...   Arabic
# 2  مجرد التفكير في تلك الأم المسكينة النرجسية كان...   Arabic
# 3  لقد كان حلمًا مغرورًا جدًا يا أمي ، فأنت لا تع...   Arabic
# 4  وأنت تعرف أن أفضل جزء منه كان عندما كنت أرتدي ...   Arabic
# Dataset after cleaning:
#                                          Cleaned_Text Language
# 0  برنامج لازم نفهم حيث يقدم البرنامج الذي يقدمه ...   Arabic
# 1  كانت ستعيش حياتها في ذلك اليوم جاء صديقان لزيا...   Arabic
# 2  مجرد التفكير في تلك الأم المسكينة النرجسية كان...   Arabic
# 3  لقد كان حلما مغرورا جدا يا أمي  فأنت لا تعرف م...   Arabic
# 4  وأنت تعرف أن أفضل جزء منه كان عندما كنت أرتدي ...   Arabic

# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

file_path = 'new_merged_dataset.csv'
df = pd.read_csv(file_path)

word_column = 'Cleaned_Text'

df = df[df[word_column].notna() & (df[word_column] != '')]

tokenizer = Tokenizer()

tokenizer.fit_on_texts(df[word_column])

sequences = tokenizer.texts_to_sequences(df[word_column])


max_length = max([len(seq) for seq in sequences])
padded_sequences = pad_sequences(sequences, padding='post', maxlen=max_length)

# Print the first 5 padded sequences
print(padded_sequences[:5])

df['padded_sequences'] = list(padded_sequences)
# Out:
# [[  4854   7363  65085 ...      0      0      0]
#  [   651 105871 105872 ...      0      0      0]
#  [ 21846  36719     22 ...      0      0      0]
#  [  3219    285  65093 ...      0      0      0]
#  [ 19191   8281    132 ...      0      0      0]]

# %%
# Save the updated dataset
output_path = 'final_dataset.csv'
df.to_csv(output_path, index=False)

print(f"Processed dataset saved to {output_path}")
# Out:
# Processed dataset saved to final_dataset.csv

# %%
import joblib
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# File path and dataset loading
dataset_path = 'Lingual_data_cleaned.csv'
data = pd.read_csv(dataset_path)

# Specify the column containing cleaned text
text_column = 'Cleaned_Text'

# Initialize CountVectorizer with a feature limit
vectorizer = CountVectorizer(max_features=10000)

# Transform the text column into feature vectors
features = vectorizer.fit_transform(data[text_column]).toarray()

# Save the vectorizer model for reuse
vectorizer_filename = 'lingual_vectorizer.pkl'
joblib.dump(vectorizer, vectorizer_filename)

print(f"Vectorizer has been saved as '{vectorizer_filename}'")
# Out:
# Vectorizer has been saved as 'lingual_vectorizer.pkl'

# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pickle

# Load the dataset
data_file = "Lingual_data_cleaned.csv"
dataset = pd.read_csv(data_file)

# Extract features and labels
text_data = dataset['Cleaned_Text'].astype(str).values
language_labels = dataset['Language'].values

# Encode the labels
label_encoder = LabelEncoder()
numeric_labels = label_encoder.fit_transform(language_labels)

# Tokenization
max_words = 10000
tokenizer = Tokenizer(num_words=max_words, oov_token="<UNK>")  # Use "<UNK>" for unknown words
tokenizer.fit_on_texts(text_data)

# Text to sequences
text_sequences = tokenizer.texts_to_sequences(text_data)

# Padding sequences
sequence_length = 120  # Adjusted sequence length
padded_texts = pad_sequences(text_sequences, maxlen=sequence_length, padding='post', truncating='post')

# Split data
X_train, X_test, y_train, y_test = train_test_split(padded_texts, numeric_labels, test_size=0.2, random_state=42)

# Build the LSTM model
lstm_model = Sequential([
    Embedding(input_dim=max_words, output_dim=128, input_length=sequence_length),
    LSTM(128, return_sequences=True),
    Dropout(0.3),  # Increased dropout for regularization
    LSTM(64),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile the model
lstm_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
training_history = lstm_model.fit(
    X_train, y_train,
    epochs=12,  # Adjusted epochs
    batch_size=64,
    validation_data=(X_test, y_test)
)

# Evaluate the model
eval_loss, eval_accuracy = lstm_model.evaluate(X_test, y_test, verbose=0)
print(f"Model Evaluation - Accuracy: {eval_accuracy:.2f}")

# Save the model
model_filename = 'LSTM_NEW_model.h5'
lstm_model.save(model_filename)
print(f"Model has been saved as '{model_filename}'")

# Save the tokenizer and label encoder
tokenizer_file = 'tokenizer_new.pkl'
label_encoder_file = 'label_encoder_new.pkl'

with open(tokenizer_file, 'wb') as token_file:
    pickle.dump(tokenizer, token_file)

with open(label_encoder_file, 'wb') as encoder_file:
    pickle.dump(label_encoder, encoder_file)

print(f"Tokenizer saved as '{tokenizer_file}'")
print(f"Label encoder saved as '{label_encoder_file}'")
# Out:
# Epoch 1/12
# C:\Users\prama\anaconda3\envs\LingualSenseNew\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 100s 238ms/step - accuracy: 0.0708 - loss: 3.2657 - val_accuracy: 0.0534 - val_loss: 3.4270
# Epoch 2/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 122s 304ms/step - accuracy: 0.0716 - loss: 3.2080 - val_accuracy: 0.0791 - val_loss: 3.2501
# Epoch 3/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 123s 305ms/step - accuracy: 0.0880 - loss: 3.1001 - val_accuracy: 0.1841 - val_loss: 2.3938
# Epoch 4/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 121s 300ms/step - accuracy: 0.2160 - loss: 2.2784 - val_accuracy: 0.3056 - val_loss: 1.7925
# Epoch 5/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 126s 313ms/step - accuracy: 0.3516 - loss: 1.7393 - val_accuracy: 0.5091 - val_loss: 1.2469
# Epoch 6/12
# ...

# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pickle

# Load the dataset
data_file = "Lingual_data_cleaned.csv"
dataset = pd.read_csv(data_file)

# Extract features and labels
text_data = dataset['Cleaned_Text'].astype(str).values
language_labels = dataset['Language'].values

# Encode the labels
label_encoder = LabelEncoder()
numeric_labels = label_encoder.fit_transform(language_labels)

# Tokenization
max_words = 10000
tokenizer = Tokenizer(num_words=max_words, oov_token="<UNK>")  # Use "<UNK>" for unknown words
tokenizer.fit_on_texts(text_data)

# Text to sequences
text_sequences = tokenizer.texts_to_sequences(text_data)

# Padding sequences
sequence_length = 120  # Adjusted sequence length
padded_texts = pad_sequences(text_sequences, maxlen=sequence_length, padding='post', truncating='post')

# Split data
X_train, X_test, y_train, y_test = train_test_split(padded_texts, numeric_labels, test_size=0.2, random_state=42)

# Build the GRU model
gru_model = Sequential([
    Embedding(input_dim=max_words, output_dim=128, input_length=sequence_length),
    GRU(128, return_sequences=True),
    Dropout(0.3),  # Increased dropout for regularization
    GRU(64),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile the model
gru_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
training_history = gru_model.fit(
    X_train, y_train,
    epochs=12,  # Adjusted epochs
    batch_size=64,
    validation_data=(X_test, y_test)
)

# Evaluate the model
eval_loss, eval_accuracy = gru_model.evaluate(X_test, y_test, verbose=0)
print(f"Model Evaluation - Accuracy: {eval_accuracy:.2f}")

# Save the model
model_filename = 'GRU_NEW_model.h5'
gru_model.save(model_filename)
print(f"Model has been saved as '{model_filename}'")

# Save the tokenizer and label encoder
tokenizer_file = 'tokenizer_gru_new.pkl'
label_encoder_file = 'label_encoder_gru_new.pkl'

with open(tokenizer_file, 'wb') as token_file:
    pickle.dump(tokenizer, token_file)

with open(label_encoder_file, 'wb') as encoder_file:
    pickle.dump(label_encoder, encoder_file)

print(f"Tokenizer saved as '{tokenizer_file}'")
print(f"Label encoder saved as '{label_encoder_file}'")
# Out:
# Epoch 1/12
# C:\Users\prama\anaconda3\envs\LingualSenseNew\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 124s 289ms/step - accuracy: 0.0733 - loss: 3.2801 - val_accuracy: 0.1176 - val_loss: 3.0160
# Epoch 2/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 106s 263ms/step - accuracy: 0.3641 - loss: 2.1754 - val_accuracy: 0.8862 - val_loss: 0.4671
# Epoch 3/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 106s 262ms/step - accuracy: 0.9065 - loss: 0.3948 - val_accuracy: 0.9252 - val_loss: 0.2729
# Epoch 4/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 108s 267ms/step - accuracy: 0.9305 - loss: 0.2581 - val_accuracy: 0.9295 - val_loss: 0.2494
# Epoch 5/12
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 106s 263ms/step - accuracy: 0.9293 - loss: 0.2396 - val_accuracy: 0.9273 - val_loss: 0.2464
# Epoch 6/12
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

gru_history = training_history.history

gru_train_acc = gru_history["accuracy"]
gru_val_acc = gru_history["val_accuracy"]

# Create epochs range
epochs = range(1, len(lstm_train_acc) + 1)

# Plot the training and validation accuracy
plt.figure(figsize=(14, 8))


# GRU Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, gru_train_acc, label="GRU Training Accuracy", marker='o')
plt.plot(epochs, gru_val_acc, label="GRU Validation Accuracy", marker='x')
plt.title("GRU Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# Show the plots
plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
import pickle
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load the saved models
gru_model = tf.keras.models.load_model('GRU_NEW_model.h5')
lstm_model = tf.keras.models.load_model('LSTM_NEW_model.h5')

# Load the tokenizers and label encoders
with open('tokenizer_gru_new.pkl', 'rb') as f:
    tokenizer_gru = pickle.load(f)

with open('tokenizer_new.pkl', 'rb') as f:
    tokenizer_lstm = pickle.load(f)

with open('label_encoder_gru_new.pkl', 'rb') as f:
    label_encoder_gru = pickle.load(f)

with open('label_encoder_new.pkl', 'rb') as f:
    label_encoder_lstm = pickle.load(f)

# Define a function to preprocess and pad the sentences
def preprocess_new_text(sentence, tokenizer, max_length=120):
    # Tokenize the sentence and convert it into a sequence of integers
    tokenized_text = tokenizer.texts_to_sequences([sentence])
    
    # Pad the sequence to ensure it is of consistent length
    padded_text = pad_sequences(tokenized_text, maxlen=max_length, padding='post', truncating='post')
    
    return padded_text

# Define a function to predict the language using a specific model
def predict_language(model_name, text):
    if model_name == 'GRU':
        tokenizer = tokenizer_gru
        model = gru_model
        label_encoder = label_encoder_gru
    elif model_name == 'LSTM':
        tokenizer = tokenizer_lstm
        model = lstm_model
        label_encoder = label_encoder_lstm
    else:
        return "Invalid model name"

    # Preprocess the input text
    padded_seq = preprocess_new_text(text, tokenizer)

    # Make the prediction
    prediction = model.predict(padded_seq)
    predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])
    return predicted_label[0]

# Dictionary of example sentences in each language
test_sentences = {
    "Arabic": "مرحبًا بك في عالم اللغة والتواصل. اللغة هي جسر يجمع الناس من مختلف الثقافات والخلفيات. عندما تتعلم لغة جديدة، فإنك تفتح بابًا لفهم الآخرين بشكل أعمق وتوسيع آفاقك.",
    "Chinese": "语言是人与人之间沟通的重要工具。通过学习一种新语言，我们可以更好地了解不同文化的背景和习俗，同时扩大我们的国际视野。",
    "Danish": "Sprog er en nøgle til forståelse og forbindelse mellem mennesker. Når vi lærer et nyt sprog, åbner vi døre til nye kulturer og oplevelser, der kan berige vores liv.",
    "Dutch": "Taal is een krachtig middel om mensen met elkaar te verbinden. Door een nieuwe taal te leren, kunnen we de wereld om ons heen beter begrijpen en verschillende perspectieven ontdekken.",
    "English": "Language is a bridge that connects people from diverse cultures. Learning a new language not only broadens your horizons but also deepens your understanding of the world and its many traditions.",
    "Estonian": "Keel on võimas tööriist inimeste vahelise suhtluse jaoks. Uue keele õppimine avab ukse uutele võimalustele ja aitab mõista erinevaid kultuure.",
    "French": "La langue est un outil puissant pour établir des liens entre les gens. Apprendre une nouvelle langue permet de découvrir de nouvelles cultures et d'élargir ses horizons.",
    "German": "Sprache ist ein wichtiger Schlüssel zur Verbindung von Menschen. Das Erlernen einer neuen Sprache eröffnet die Möglichkeit, andere Kulturen zu verstehen und die Welt anders zu sehen.",
    "Greek": "Η γλώσσα είναι ένα εργαλείο που συνδέει τους ανθρώπους. Μαθαίνοντας μια νέα γλώσσα, ανοίγουμε πόρτες σε διαφορετικούς πολιτισμούς και εμπειρίες.",
    "Hindi": "भाषा लोगों को जोड़ने का एक महत्वपूर्ण साधन है। एक नई भाषा सीखने से न केवल हमारी समझ बढ़ती है, बल्कि हमें अलग-अलग संस्कृतियों और परंपराओं को गहराई से समझने का मौका भी मिलता है।",
    "Indonesian": "Bahasa adalah alat penting untuk menghubungkan orang dari berbagai latar belakang. Dengan mempelajari bahasa baru, kita dapat memahami budaya lain dengan lebih baik dan memperluas wawasan kita.",
    "Italian": "La lingua è uno strumento fondamentale per connettere le persone. Imparare una nuova lingua apre le porte a nuove culture e modi di pensare.",
    "Japanese": "言語は人と人をつなぐ架け橋です。新しい言語を学ぶことで、異なる文化や伝統を深く理解し、視野を広げることができます。",
    "Kannada": "ಭಾಷೆ ಜನರನ್ನು ಸಂಪರ್ಕಿಸಲು ಒಂದು ಮುಖ್ಯ ಸಾಧನವಾಗಿದೆ. ಹೊಸ ಭಾಷೆಯನ್ನು ಕಲಿಯುವುದರಿಂದ ನಮ್ಮ ಅರಿವು ಹೆಚ್ಚಾಗುತ್ತದೆ ಮತ್ತು ವಿವಿಧ ಸಂಸ್ಕೃತಿಗಳನ್ನು ಒಳಗೊಂಡು ನೋಡಲು ಸಾಧ್ಯವಾಗುತ್ತದೆ.",
    "Korean": "언어는 사람들을 연결하는 중요한 도구입니다. 새로운 언어를 배우면 다른 문화와 전통을 깊이 이해하고 시야를 넓힐 수 있습니다.",
    "Latin": "Lingua est instrumentum humanitatis ad coniungendos populos. Novam linguam discendo, portas aperimus ad culturas varias et novas perspective.",
    "Malayalam": "ഭാഷ മനുഷ്യരെ ബന്ധിപ്പിക്കുന്ന ഒരു പ്രധാന ഉപകരണമാണ്. ഒരു പുതിയ ഭാഷ പഠിക്കുന്നത്, നിങ്ങൾക്ക് വിവിധ സാംസ്കാരികങ്ങളെ കുറിച്ച് കൂടുതൽ മനസിലാക്കാനും നിങ്ങളുടെ കാഴ്ചപ്പാട് വികസിപ്പിക്കാനും സഹായിക്കുന്നു.",
    "Persian": "زبان ابزار مهمی برای برقراری ارتباط بین افراد است. یادگیری یک زبان جدید درک عمیق‌تری از فرهنگ‌ها و سنت‌های مختلف به ما می‌دهد.",
    "Portuguese": "A linguagem é uma ponte que conecta pessoas de culturas diferentes. Aprender um novo idioma amplia seus horizontes e aprofunda sua compreensão do mundo.",
    "Pushto": "ژبه د خلکو تر منځ د اړیکو لپاره یو مهم وسیله ده. د یوې نوې ژبې زده کړه د مختلفو کلتورونو او دودونو د ښه پوهیدو لپاره دروازې پرانیزي.",
    "Romanian": "Limba este un mijloc esențial de conectare între oameni. Învățarea unei limbi noi deschide uși către noi culturi și perspective.",
    "Russian": "Язык является важным инструментом общения между людьми. Изучая новый язык, мы открываем для себя новые культуры и расширяем кругозор.",
    "Spanish": "El lenguaje es un puente que conecta a las personas de diferentes culturas. Aprender un nuevo idioma no solo amplía tus horizontes, sino que también profundiza tu comprensión del mundo.",
    "Swedish": "Språk är en bro som förenar människor från olika kulturer. Att lära sig ett nytt språk öppnar dörrar till nya upplevelser och förståelse.",
    "Tamil": "மொழி மனிதர்களை இணைக்கும் ஒரு முக்கிய சாதனமாகும். புதிய மொழியை கற்றுக்கொள்வதால் நாம் பல்வேறு பண்பாடுகளை புரிந்துகொள்ள முடியும்.",
    "Thai": "ภาษาเป็นเครื่องมือสำคัญที่เชื่อมโยงผู้คนจากหลากหลายวัฒนธรรม การเรียนรู้ภาษาที่สามช่วยขยายมุมมองและความเข้าใจต่อโลกและวัฒนธรรมอื่น ๆ",
    "Turkish": "Dil, farklı kültürlerden insanları birleştiren bir köprüdür. Yeni bir dil öğrenmek, ufkunuzu genişletir ve dünyayı daha iyi anlamanızı sağlar.",
    "Urdu": "زبان لوگوں کو جوڑنے کا ایک اہم ذریعہ ہے۔ نئی زبان سیکھنا نہ صرف آپ کی سمجھ کو گہرا کرتا ہے بلکہ مختلف ثقافتوں اور روایات کو سمجھنے کا موقع بھی فراہم کرتا ہے۔"
}

# Preprocess and predict for each sentence
for language, sentence in test_sentences.items():
    # Predict the language using both models
    gru_predicted_language = predict_language('GRU', sentence)
    lstm_predicted_language = predict_language('LSTM', sentence)
    
    # Print results
    print(f"Actual Language: {language}")
    print(f"Predicted Language (GRU): {gru_predicted_language}")
    print(f"Predicted Language (LSTM): {lstm_predicted_language}")
    print(f"Test Sentence: {sentence}\n")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# Actual Language: Arabic
# Predicted Language (GRU): Arabic
# Predicted Language (LSTM): Arabic
# Test Sentence: مرحبًا بك في عالم اللغة والتواصل. اللغة هي جسر يجمع الناس من مختلف الثقافات والخلفيات. عندما تتعلم لغة جديدة، فإنك تفتح بابًا لفهم الآخرين بشكل أعمق وتوسيع آفاقك.
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Actual Language: Chinese
# Predicted Language (GRU): Chinese
# Predicted Language (LSTM): Japanese
# Test Sentence: 语言是人与人之间沟通的重要工具。通过学习一种新语言，我们可以更好地了解不同文化的背景和习俗，同时扩大我们的国际视野。
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# ...
